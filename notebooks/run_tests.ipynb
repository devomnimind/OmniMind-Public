# %%
import os
import sys

# Garantir que estamos na raiz do projeto
project_root = os.path.abspath("..")
if os.getcwd() != project_root:
    os.chdir(project_root)
    print(f"📂 Working directory set to: {os.getcwd()}")

# %% [markdown]
# ## 1. 🚀 End-to-End (E2E) Tests
# Testes de integração completa do sistema.

# %%
# !pytest tests/test_e2e_integration.py -v --tb=short

# %% [markdown]
# ## 2. 🧠 Memory Systems
# Testes de memória episódica, semântica e procedural.

# %%
# !pytest tests/memory/ -v --tb=short

# %% [markdown]
# ## 3. ⚛️ Quantum Consciousness
# Testes dos módulos de consciência quântica e algoritmos híbridos.

# %%
# !pytest tests/quantum_consciousness/ tests/quantum_ai/ -v --tb=short

# %% [markdown]
# ## 4. 🛡️ Security & Ethics
# Testes de segurança, auditoria e ética estrutural.

# %%
# !pytest tests/security/ tests/ethics/ -v --tb=short

# %% [markdown]
# ## 5. 🏃 Run All Tests (Background)
# Executa todos os testes (pode demorar).

# %%
# !pytest tests/ -v --tb=short --maxfail=10
